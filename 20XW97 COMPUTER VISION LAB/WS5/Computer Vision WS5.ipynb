# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---                                      3.4/38.8 MB 26.9 kB/s eta 0:21:56
# ERROR: Wheel 'opencv-python' located at C:\Users\TEMP.WINSERVER\AppData\Local\Temp\pip-unpack-5jwwbh_y\opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl is invalid.

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 38.8/38.8 MB 129.0 kB/s eta 0:00:00
# ...

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
f = cv2.imread("cameraman.tif",0)

# %%
f
# Out:
# array([[156, 159, 158, ..., 151, 152, 152],
#        [160, 154, 157, ..., 154, 155, 153],
#        [156, 159, 158, ..., 151, 152, 152],
#        ...,
#        [114, 132, 123, ..., 135, 137, 114],
#        [121, 126, 130, ..., 133, 130, 113],
#        [121, 126, 130, ..., 133, 130, 113]], dtype=uint8)

# %%
h = np.zeros([256,256])
h[2,1] = 1

# %%
g = cv2.filter2D(f,-1,h)

# %%
plt.imshow(f,cmap="gray")
plt.title("Input")
# Out:
# Text(0.5, 1.0, 'Input')

# %%
plt.imshow(g,cmap="gray")
plt.title("Output")
# Out:
# Text(0.5, 1.0, 'Output')

# %% [markdown]
# ##Inference Convolution of any impulse function will give the same function

# %% [markdown]
# ## Exercise 2

# %%
f = np.zeros([256,256])
f[0:256,0:128] = 255

# %%
M =21
h = 1/(M*M)*np.ones([M,M])

# %%
g = cv2.filter2D(f,-1,h)

# %%
plt.imshow(f,cmap="gray")
plt.title("Input")
# Out:
# Text(0.5, 1.0, 'Input')

# %%
plt.imshow(g,cmap="gray")
plt.title("Output")
# Out:
# Text(0.5, 1.0, 'Output')

# %% [markdown]
# ### When ever image is passed through the low pass fliter and loss of detail/edge
# ### increasing the mask size will defintely increase the blurring

# %% [markdown]
# ### Box Fliter  Averaging  fliter is used here

# %% [markdown]
# ## Exercise 3

# %%
M =21
h = 1/(M*M)*np.ones([M,M])

# %%
g = cv2.filter2D(f,-1,h)

# %% [markdown]
# ## Exercise 4

# %%
M =21
h1 = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
h2 = np.array([[-1,-1,-1],[-1,11,-1],[-1,-1,-1]])

# %%
g1 = cv2.filter2D(f,-1,h1)
g2 = cv2.filter2D(f,-1,h2)

# %%
plt.imshow(f,cmap="gray")
plt.title("Input")
# Out:
# Text(0.5, 1.0, 'Input')

# %%
plt.imshow(g1,cmap="gray")
plt.title("Output")
# Out:
# Text(0.5, 1.0, 'Output')

# %%
plt.imshow(g2,cmap="gray")
plt.title("Output")
# Out:
# Text(0.5, 1.0, 'Output')

# %% [markdown]
# ### High Pass Filter
# #### to extract the edge information
# #### but the background image is lost

# %%
mask = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])

# %%
H = np.fft.fftshift(np.fft.fft2(mask))

# %%
plt.imshow(np.abs(H),cmap='gray')

# %%
mask1 = np.array([[1,2,1],[2,4,-2],[1,2,1]])

# %%
H1 = np.fft.fftshift(np.fft.fft2(mask1))

# %%
plt.imshow(np.abs(H1),cmap='gray')
