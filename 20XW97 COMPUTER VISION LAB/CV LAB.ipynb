# %%
# !pip install sounddevice
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sounddevice
#   Downloading sounddevice-0.4.7-py3-none-win_amd64.whl (200 kB)
#      ------------------------------------ 200.1/200.1 kB 935.3 kB/s eta 0:00:00
# Requirement already satisfied: CFFI>=1.0 in c:\programdata\anaconda3\lib\site-packages (from sounddevice) (1.15.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice) (2.21)
# Installing collected packages: sounddevice
# Successfully installed sounddevice-0.4.7

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0,1,100)
f = 1

# %%
x = np.sin(2*np.pi*f*t)

# %%
plt.plot(t,x)

# %%
f = 0

# %%
x = np.sin(2*np.pi*f*t)

# %%
plt.plot(t,x)

# %%
## When The Rate of Chage of Signal is Zero we call DC Signal

# %% [markdown]
# # Program 2

# %% [markdown]
# Hear an Sine Wave

# %%
import sounddevice as sd
import numpy as np

# %%
fs = 8000
t = np.linspace(0,1,fs)

# %%
f1 = 270
f2 = 300
f3 = 320
f4 = 360
f5 = 400
f6 = 450
f7 = 480

# %%
f = 50
x1 = np.sin(2*np.pi*f1)

# %%
x = np.concatenate([x1,x2,x3])

# %%
sd.play(x,fs)
